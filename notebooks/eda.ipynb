# %%
import os.path

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from misc import DATA_DIR

# %% [markdown]
# # Districts

# %%
df = pd.read_csv('../dataset/map/districts.csv', header=None, names=['ID', 'Name', 'Region'])

# Plot the distribution of regions
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Region')
plt.title('Distribution of Regions')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks()
plt.show()

# %% [markdown]
# # Voting Sites
